# %%
import turkish_tokenizer as tt

myDict = tt.reverse_dict

# %%
myDict
# Out:
# {0: ['<uppercase>'],
#  1: ['<space>'],
#  2: ['<newline>'],
#  3: ['<tab>'],
#  4: ['<unknown>'],
#  5: ['special_5'],
#  6: ['special_6'],
#  7: ['special_7'],
#  8: ['special_8'],
#  9: ['special_9'],
#  10: ['special_10'],
#  11: ['special_11'],
#  12: ['special_12'],
#  13: ['special_13'],
#  14: ['special_14'],
#  15: ['special_15'],
#  16: ['special_16'],
#  17: ['special_17'],
#  18: ['special_18'],
#  19: ['special_19'],
#  20: ['special_20'],
#  21: ['special_21'],
#  22: ['special_22'],
#  23: ['special_23'],
#  24: ['special_24'],
#  25: ['special_25'],
#  26: ['special_26'],
#  27: ['special_27'],
#  28: ['special_28'],
#  29: ['special_29'],
#  30: ['special_30'],
#  31: ['special_31'],
#  32: ['special_32'],
#  33: ['special_33'],
#  34: ['special_34'],
#  35: ['special_35'],
#  36: ['special_36'],
#  37: ['special_37'],
#  38: ['special_38'],
#  39: ['special_39'],
#  40: ['special_40'],
#  41: ['special_41'],
#  42: ['special_42'],
#  43: ['special_43'],
#  44: ['special_44'],
#  45: ['special_45'],
#  46: ['special_46'],
#  47: ['special_47'],
#  48: ['special_48'],
#  49: ['special_49'],
#  50: ['special_50'],
#  51: ['special_51'],
#  52: ['special_52'],
#  53: ['special_53'],
#  54: ['special_54'],
#  55: ['special_55'],
#  56: ['special_56'],
#  57: ['special_57'],
#  58: ['special_58'],
#  59: ['special_59'],
#  60: ['special_60'],
#  61: ['special_61'],
#  62: ['special_62'],
#  63: ['special_63'],
#  64: ['special_64'],
#  65: ['special_65'],
#  66: ['special_66'],
#  67: ['special_67'],
#  68: ['special_68'],
#  69: ['special_69'],
#  70: ['special_70'],
#  71: ['special_71'],
#  72: ['special_72'],
#  73: ['special_73'],
#  74: ['special_74'],
#  75: ['special_75'],
#  76: ['special_76'],
#  77: ['special_77'],
#  78: ['special_78'],
#  79: ['special_79'],
#  80: ['special_80'],
#  81: ['special_81'],
#  82: ['special_82'],
#  83: ['special_83'],
#  84: ['special_84'],
#  85: ['special_85'],
#  86: ['special_86'],
#  87: ['special_87'],
#  88: ['special_88'],
#  89: ['special_89'],
#  90: ['special_90'],
#  91: ['special_91'],
#  92: ['special_92'],
#  93: ['special_93'],
#  94: ['special_94'],
#  95: ['special_95'],
#  96: ['special_96'],
#  97: ['special_97'],
#  98: ['special_98'],
#  99: ['special_99'],
#  100: ['bir'],
#  101: ['ol'],
#  102: ['bu'],
#  103: ['et', 'ed'],
#  104: ['kullan'],
#  105: ['daha'],
#  106: ['edi'],
#  107: ['en'],
#  108: ['çok', 'çoğ'],
#  109: ['al'],
#  110: ['yap', 'yab'],
#  111: ['veri'],
#  112: ['bulun'],
#  113: ['taraf'],
#  114: ['yıl'],
#  115: ['yer'],
#  116: ['her'],
#  117: ['zaman'],
#  118: ['site'],
#  119: ['ne'],
#  120: ['alan'],
#  121: ['gerek', 'gereğ'],
#  122: ['bilgi'],
#  123: ['konu'],
#  124: ['kişi'],
#  125: ['kendi'],
#  126: ['son'],
#  127: ['şekil', 'şekl'],
#  128: ['yeni'],
#  129: ['var'],
#  130: ['başla', 'başlı'],
#  131: ['iyi'],
#  132: ['aras'],
#  133: ['gel'],
#  134: ['süre'],
#  135: ['durum'],
#  136: ['yapıl'],
#  137: ['büyük', 'büyüğ'],
#  138: ['hizmet'],
#  139: ['sahip', 'sahib'],
#  140: ['değil'],
#  141: ['iki'],
#  142: ['es'],
#  143: ['ilk'],
#  144: ['bun'],
#  145: ['fazla'],
#  146: ['ilgi'],
#  147: ['sağla', 'sağlı'],
#  148: ['gün'],
#  149: ['ürün'],
#  150: ['üzeri'],
#  151: ['tüm'],
#  152: ['neden'],
#  153: ['önemli'],
#  154: ['ede'],
#  155: ['film'],
#  156: ['şey'],
#  157: ['eder'],
#  158: ['yan'],
#  159: ['diğer'],
#  160: ['insan'],
#  161: ['kal'],
#  162: ['çalış'],
#  163: ['ver'],
#  164: ['biri'],
#  165: ['aynı'],
#  166: ['yardım'],
#  167: ['anlam'],
#  168: ['oyun'],
#  169: ['soru'],
#  170: ['devam'],
#  171: ['nasıl'],
#  172: ['fark'],
#  173: ['özel'],
#  174: ['sistem'],
#  175: ['iç'],
#  176: ['tarih'],
#  177: ['sorun'],
#  178: ['ön'],
#  179: ['ben'],
#  180: ['açıkla', 'açıklı'],
#  181: ['th'],
#  182: ['birlik', 'birliğ'],
#  183: ['hakkında'],
#  184: ['ev'],
#  185: ['görev'],
#  186: ['co'],
#  187: ['adres'],
#  188: ['cümle'],
#  189: ['sayı'],
#  190: ['şu'],
#  191: ['üye'],
#  192: ['olur'],
#  193: ['yol'],
#  194: ['bahis'],
#  195: ['kazan'],
#  196: ['alın', 'aln'],
#  197: ['kadın'],
#  198: ['hayat', 'hayad'],
#  199: ['yok'],
#  200: ['uygun'],
#  201: ['işlem'],
#  202: ['hal'],
#  203: ['yüksek', 'yükseğ'],
#  204: ['gerçekleş'],
#  205: ['karar'],
#  206: ['ülke'],
#  207: ['yaşa', 'yaşı'],
#  208: ['izle', 'izli'],
#  209: ['ifade'],
#  210: ['yayın'],
#  211: ['biz'],
#  212: ['değer'],
#  213: ['altın'],
#  214: ['ulaş'],
#  215: ['iş'],
#  216: ['yaş'],
#  217: ['uygulama'],
#  218: ['kabul'],
#  219: ['para'],
#  220: ['and'],
#  221: ['bölge'],
#  222: ['belirle'],
#  223: ['çıkar'],
#  224: ['dünya'],
#  225: ['haber'],
#  226: ['tek', 'teğ'],
#  227: ['özellik', 'özelliğ'],
#  228: ['dönem'],
#  229: ['saat'],
#  230: ['yapı'],
#  231: ['oyna', 'oynu'],
#  232: ['söyle', 'söylü'],
#  233: ['bazı'],
#  234: ['web'],
#  235: ['uzun'],
#  236: ['çocuk', 'çocuğ'],
#  237: ['başka'],
#  238: ['ara'],
#  239: ['etki'],
#  240: ['görü'],
#  241: ['firma'],
#  242: ['bağlantı'],
#  243: ['el'],
#  244: ['güzel'],
#  245: ['düşün'],
#  246: ['diye'],
#  247: ['giriş'],
#  248: ['onlar'],
#  249: ['on'],
#  250: ['bil'],
#  251: ['gir'],
#  252: ['futbol'],
#  253: ['sıra'],
#  254: ['bağlı'],
#  255: ['geri'],
#  256: ['küçük', 'küçüğ'],
#  257: ['bile', 'bili'],
#  258: ['getir'],
#  259: ['dil'],
#  260: ['sadece'],
#  261: ['eğitim'],
#  262: ['az'],
#  263: ['dikkat'],
#  264: ['şirket'],
#  265: ['yakın'],
#  266: ['arkadaş'],
#  267: ['at'],
#  268: ['bura'],
#  269: ['çeşit', 'çeşid'],
#  270: ['belirti'],
#  271: ['hareket', 'hareked'],
#  272: ['dış'],
#  273: ['açık', 'açığ'],
#  274: ['madde'],
#  275: ['kız'],
#  276: ['güven'],
#  277: ['adım'],
#  278: ['ilişki'],
#  279: ['ortay'],
#  280: ['kolay'],
#  281: ['takım'],
#  282: ['oku'],
#  283: ['takip', 'takib'],
#  284: ['genel'],
#  285: ['is'],
#  286: ['kelime'],
#  287: ['katıl'],
#  288: ['açı'],
#  289: ['gelir'],
#  290: ['herhangi'],
#  291: ['bölüm'],
#  292: ['birçok', 'birçoğ'],
#  293: ['oyuncu'],
#  294: ['düzen'],
#  295: ['kalite'],
#  296: ['müşteri'],
#  297: ['model'],
#  298: ['aile'],
#  299: ['ala'],
#  300: ['başı'],
#  301: ['kullanım'],
#  302: ['kontrol'],
#  303: ['yaz'],
#  304: ['olay'],
#  305: ['gösteri'],
#  306: ['yüzde'],
#  307: ['edebi'],
#  308: ['sayfa'],
#  309: ['satın'],
#  310: ['git', 'gid'],
#  311: ['art'],
#  312: ['porno'],
#  313: ['aşağı'],
#  314: ['ekle'],
#  315: ['cevap', 'cevab'],
#  316: ['paylaş'],
#  317: ['yorum'],
#  318: ['kapsam'],
#  319: ['ücret'],
#  320: ['canlı'],
#  321: ['sağlama'],
#  322: ['göz'],
#  323: ['tarif'],
#  324: ['elde'],
#  325: ['adam'],
#  326: ['tam'],
#  327: ['ali'],
#  328: ['tercih'],
#  329: ['edin'],
#  330: ['o'],
#  331: ['kısa'],
#  332: ['sağlık', 'sağlığ'],
#  333: ['maç'],
#  334: ['uygula', 'uygulu'],
#  335: ['üç', 'üc'],
#  336: ['bo'],
#  337: ['ard'],
#  338: ['mümkün'],
#  339: ['kay'],
#  340: ['deneyim'],
#  341: ['onun'],
#  342: ['telefon'],
#  343: ['başvuru'],
#  344: ['hafta'],
#  345: ['öğren'],
#  346: ['temel'],
#  347: ['eski'],
#  348: ['hiçbir'],
#  349: ['geç'],
#  350: ['derece'],
#  351: ['ilişkin'],
#  352: ['bırak'],
#  353: ['kumaş'],
#  354: ['yön'],
#  355: ['hangi'],
#  356: ['sev'],
#  357: ['öğrenci'],
#  358: ['ek'],
#  359: ['yöntem'],
#  360: ['aracı'],
#  361: ['liste'],
#  362: ['yazar'],
#  363: ['hasta'],
#  364: ['ay'],
#  365: ['erkek', 'erkeğ'],
#  366: ['nokta'],
#  367: ['aç', 'ac'],
#  368: ['çıktı'],
#  369: ['kez'],
#  370: ['proje'],
#  371: ['yaşam'],
#  372: ['değişik', 'değişiğ'],
#  373: ['kaynak', 'kaynağ'],
#  374: ['fiyat'],
#  376: ['isim'],
#  377: ['gerçek', 'gerçeğ'],
#  378: ['dahil'],
#  379: ['seç', 'sec'],
#  380: ['seçenek', 'seçeneğ'],
#  381: ['parça'],
#  382: ['ödem'],
#  383: ['araç', 'arac'],
#  384: ['söz'],
#  385: ['şarkı'],
#  386: ['belirt', 'belird'],
#  387: ['hızlı'],
#  388: ['doğum'],
#  389: ['ikinci'],
#  390: ['ilçe'],
#  391: ['destek', 'desteğ'],
#  392: ['sosyal'],
#  393: ['sun'],
#  394: ['resim', 'resm'],
#  395: ['boyunca'],
#  396: ['bin'],
#  397: ['video'],
#  398: ['bekle', 'bekli'],
#  399: ['güncel'],
#  400: ['merkez'],
#  401: ['gör'],
#  402: ['sanat'],
#  403: ['şehir', 'şehr'],
#  404: ['hak'],
#  405: ['hava'],
#  406: ['sahi'],
#  407: ['bütün'],
#  408: ['ortam'],
#  409: ['sağ'],
#  410: ['dakika'],
#  411: ['yatırım'],
#  412: ['iletişim'],
#  413: ['sunu'],
#  414: ['genç', 'genc'],
#  415: ['inceleme'],
#  416: ['sorumlu'],
#  417: ['başarı'],
#  418: ['yapım'],
#  419: ['mevcut'],
#  420: ['hiç'],
#  421: ['nüfus'],
#  422: ['ana'],
#  423: ['çalışan'],
#  424: ['tedavi'],
#  425: ['savaş'],
#  426: ['değiş'],
#  427: ['izin', 'izn'],
#  428: ['bakım'],
#  429: ['dizi'],
#  430: ['bul'],
#  431: ['alt', 'ald'],
#  432: ['enerji'],
#  433: ['hemen'],
#  434: ['baş'],
#  435: ['servis'],
#  436: ['yemek', 'yemeğ'],
#  437: ['yazı'],
#  438: ['yüz'],
#  439: ['tanı'],
#  440: ['internet'],
#  441: ['satış'],
#  442: ['bayan'],
#  443: ['yönel'],
#  444: ['devlet'],
#  445: ['bak'],
#  446: ['il'],
#  447: ['faaliyet'],
#  448: ['köy'],
#  449: ['görüntü'],
#  450: ['program'],
#  451: ['ziyaret'],
#  452: ['hes'],
#  453: ['yönetim'],
#  454: ['analiz'],
#  455: ['dava'],
#  456: ['oran'],
#  457: ['üret', 'üred'],
#  458: ['sektör'],
#  459: ['göster'],
#  460: ['zarar'],
#  461: ['kısım', 'kısm'],
#  462: ['saye'],
#  463: ['kurum'],
#  464: ['dön'],
#  465: ['talep', 'taleb'],
#  466: ['milyon'],
#  467: ['rol'],
#  468: ['artık', 'artığ'],
#  469: ['üretim'],
#  470: ['teknoloji'],
#  471: ['ata', 'atı'],
#  472: ['oluş'],
#  473: ['iste', 'isti'],
#  474: ['malzeme'],
#  475: ['kod'],
#  476: ['tıkla', 'tıklı'],
#  477: ['mesaj'],
#  478: ['re'],
#  479: ['eş'],
#  480: ['hesap', 'hesab'],
#  481: ['okul'],
#  482: ['toplam'],
#  483: ['oda'],
#  484: ['kitap', 'kitab'],
#  485: ['dem'],
#  486: ['anne'],
#  487: ['hale'],
#  488: ['zor'],
#  489: ['ban'],
#  490: ['casino'],
#  491: ['seviye'],
#  492: ['numara'],
#  493: ['hikaye'],
#  494: ['eser'],
#  495: ['araştırma'],
#  496: ['teknik', 'tekniğ'],
#  497: ['artır'],
#  498: ['katkı'],
#  499: ['hız'],
#  500: ['kim'],
#  501: ['tekrar'],
#  502: ['hayvan'],
#  503: ['pek'],
#  504: ['sık'],
#  505: ['sen'],
#  506: ['içerik', 'içeriğ'],
#  507: ['anla', 'anlı'],
#  508: ['spor'],
#  509: ['cihaz'],
#  510: ['yaklaşık', 'yaklaşığ'],
#  511: ['kurul'],
#  512: ['halk'],
#  513: ['dolar'],
#  514: ['uzak', 'uzağ'],
#  515: ['duy'],
#  516: ['sik'],
#  517: ['plan'],
#  518: ['karakter'],
#  519: ['seks'],
#  520: ['uzman'],
#  521: ['çık'],
#  522: ['kayıt', 'kayıd'],
#  523: ['çek'],
#  524: ['arama'],
#  525: ['herkes'],
#  526: ['önem'],
#  527: ['koruma'],
#  528: ['aktar'],
#  529: ['çevre', 'çevr'],
#  530: ['makale'],
#  531: ['miktar'],
#  532: ['birkaç'],
#  533: ['yalnız'],
#  534: ['düş'],
#  535: ['çerez'],
#  536: ['kaç'],
#  537: ['gönderi'],
#  538: ['baba'],
#  539: ['tasarım'],
#  540: ['duygu'],
#  541: ['üst'],
#  542: ['istek', 'isteğ'],
#  543: ['konuşma'],
#  544: ['meydan'],
#  545: ['incele', 'inceli'],
#  546: ['medya'],
#  547: ['kuruluş'],
#  548: ['sezon'],
#  549: ['güçlü'],
#  550: ['deniz'],
#  551: ['sür'],
#  552: ['gece'],
#  553: ['sonuç', 'sonuc'],
#  554: ['tamam'],
#  555: ['karşılaş'],
#  556: ['belirli'],
#  557: ['biraz'],
#  558: ['geniş'],
#  559: ['ders'],
#  560: ['kart', 'kard'],
#  561: ['yüzyıl'],
#  562: ['yarat', 'yarad'],
#  563: ['benzer'],
#  564: ['bugün'],
#  565: ['arka'],
#  566: ['dayan'],
#  567: ['kural'],
#  568: ['par'],
#  569: ['başkan'],
#  570: ['iptal'],
#  571: ['ayrıca'],
#  572: ['yoğun'],
#  573: ['ona', 'onu'],
#  574: ['reklam'],
#  575: ['mahalle'],
#  576: ['ilan'],
#  577: ['mücadele'],
#  578: ['tespit'],
#  579: ['sınır'],
#  580: ['ortak', 'ortağ'],
#  581: ['yine'],
#  582: ['süreç', 'sürec'],
#  583: ['mutlu'],
#  584: ['kötü'],
#  585: ['resmi'],
#  586: ['öneri'],
#  587: ['öl'],
#  588: ['ayrıl'],
#  589: ['anlat', 'anlad'],
#  590: ['grup', 'grub'],
#  591: ['tamamen'],
#  592: ['şöyle'],
#  593: ['bağ'],
#  594: ['konum'],
#  595: ['ses'],
#  596: ['sitem'],
#  597: ['beraber'],
#  598: ['doğal'],
#  599: ['platform'],
#  600: ['taşı'],
#  601: ['albüm'],
#  602: ['araba'],
#  603: ['boyut'],
#  604: ['tara', 'tarı'],
#  605: ['sene'],
#  606: ['dair'],
#  608: ['parti'],
#  609: ['indir'],
#  610: ['eylem'],
#  611: ['makine'],
#  612: ['olumsuz'],
#  613: ['detay'],
#  614: ['kalan'],
#  615: ['geliş'],
#  616: ['bilim'],
#  617: ['güç', 'güc'],
#  618: ['hazır'],
#  619: ['lider'],
#  620: ['ihtiyaç', 'ihtiyac'],
#  621: ['performans'],
#  622: ['sözle'],
#  623: ['yayım'],
#  624: ['politika'],
#  625: ['ölüm'],
#  626: ['tavsiye'],
#  627: ['yani'],
#  628: ['seçim'],
#  629: ['düşük', 'düşüğ'],
#  630: ['böyle'],
#  631: ['sebep', 'sebeb'],
#  632: ['saldırı'],
#  633: ['olumlu'],
#  634: ['aday'],
#  635: ['doğrudan'],
#  636: ['risk'],
#  637: ['sefer'],
#  638: ['düzey'],
#  639: ['fayda'],
#  640: ['dövme'],
#  641: ['dört', 'dörd'],
#  642: ['sürekli'],
#  643: ['fırsat'],
#  644: ['kaldır'],
#  645: ['kardeş'],
#  646: ['geçmiş'],
#  647: ['bilgisayar'],
#  648: ['eksik', 'eksiğ'],
#  649: ['piyasa'],
#  650: ['teslim'],
#  651: ['birbiri'],
#  652: ['hata'],
#  653: ['hücre'],
#  654: ['müzik', 'müziğ'],
#  655: ['bebek', 'bebeğ'],
#  656: ['yasal'],
#  657: ['gelişme'],
#  658: ['yeter'],
#  659: ['ölçü'],
#  660: ['üçüncü'],
#  661: ['konuş'],
#  662: ['sonunda'],
#  663: ['renk', 'reng'],
#  664: ['iddia'],
#  665: ['koşul'],
#  666: ['kaydet', 'kayded'],
#  667: ['kapı'],
#  668: ['mobil'],
#  669: ['taş'],
#  670: ['hedef'],
#  671: ['ceza'],
#  672: ['yanıt'],
#  673: ['kanal'],
#  674: ['gelecek', 'geleceğ'],
#  675: ['yanlış'],
#  676: ['günlük', 'günlüğ'],
#  677: ['uyum'],
#  678: ['sıcak', 'sıcağ'],
#  679: ['sipariş'],
#  680: ['mağaza'],
#  681: ['kategori'],
#  682: ['koy'],
#  683: ['sınıf'],
#  684: ['toplum'],
#  685: ['teşekkür'],
#  686: ['şimdi'],
#  687: ['birim'],
#  688: ['rapor'],
#  689: ['çözüm'],
#  690: ['kuru'],
#  691: ['güvenlik', 'güvenliğ'],
#  692: ['banka'],
#  693: ['adet', 'aded'],
#  694: ['by'],
#  695: ['bina'],
#  696: ['gazete'],
#  697: ['kültür'],
#  698: ['yolcu'],
#  699: ['hastalık', 'hastalığ'],
#  700: ['form'],
#  701: ['bitki'],
#  702: ['profesyonel'],
#  703: ['iade'],
#  704: ['tut'],
#  705: ['itibaren'],
#  706: ['dosya'],
#  707: ['beş'],
#  708: ['gönder'],
#  709: ['emin'],
#  710: ['amaç', 'amac'],
#  711: ['marka'],
#  712: ['olası'],
#  713: ['sor'],
#  714: ['yem'],
#  715: ['nere'],
#  716: ['etkin'],
#  717: ['yerleş'],
#  718: ['inan'],
#  719: ['bağlam'],
#  720: ['eşya'],
#  721: ['hat'],
#  722: ['teklif'],
#  723: ['kent', 'kend'],
#  724: ['basit'],
#  725: ['unut'],
#  726: ['aşama'],
#  727: ['imkan'],
#  728: ['söyleme'],
#  729: ['büyü'],
#  730: ['yarı'],
#  731: ['puan'],
#  732: ['problem'],
#  733: ['zorun'],
#  734: ['lütfen'],
#  735: ['vatandaş'],
#  736: ['sat', 'sad'],
#  737: ['tanım'],
#  738: ['ayrıntı'],
#  739: ['baskı'],
#  740: ['geliştir'],
#  741: ['fikir', 'fikr'],
#  742: ['yo'],
#  743: ['biçim'],
#  744: ['ağır'],
#  745: ['test'],
#  746: ['kimse'],
#  747: ['potansiyel'],
#  748: ['ister'],
#  749: ['yönet'],
#  750: ['ayrı'],
#  751: ['tarz'],
#  752: ['anlatı'],
#  753: ['düzenleme'],
#  754: ['yazılım'],
#  755: ['kol'],
#  756: ['yaygın'],
#  757: ['verim'],
#  758: ['ayar'],
#  759: ['motor'],
#  760: ['yarar'],
#  761: ['ora'],
#  762: ['ödül'],
#  763: ['metin', 'metn'],
#  764: ['kur'],
#  765: ['mis'],
#  766: ['çoğu'],
#  767: ['kredi'],
#  768: ['açma'],
#  769: ['üstün'],
#  770: ['maliyet', 'maliyed'],
#  771: ['tasarla', 'tasarlı'],
#  772: ['saha'],
#  773: ['şart'],
#  774: ['elektrik', 'elektriğ'],
#  775: ['deneme'],
#  776: ['geçerli'],
#  777: ['hac'],
#  778: ['rahat'],
#  779: ['dolu'],
#  780: ['yakala', 'yakalı'],
#  781: ['değişim'],
#  782: ['şans'],
#  783: ['can'],
#  784: ['başlık', 'başlığ'],
#  785: ['birleş'],
#  786: ['toplantı'],
#  787: ['önlem'],
#  788: ['etkinlik', 'etkinliğ'],
#  789: ['mal'],
#  790: ['hukuk'],
#  791: ['ekran'],
#  792: ['alışveriş'],
#  793: ['üniversite'],
#  794: ['tahmin'],
#  795: ['işaret'],
#  796: ['hisse'],
#  797: ['ayır', 'ayr'],
#  798: ['olanak', 'olanağ'],
#  799: ['bet'],
#  800: ['birey'],
#  801: ['faktör'],
#  802: ['kayna', 'kaynı'],
#  803: ['çevir'],
#  804: ['hayal'],
#  805: ['erişim'],
#  806: ['kat', 'kad'],
#  807: ['yetkili'],
#  808: ['fotoğraf'],
#  809: ['bit', 'bid'],
#  810: ['kariyer'],
#  811: ['derin'],
#  812: ['bi'],
#  813: ['ekonomik', 'ekonomiğ'],
#  814: ['harf'],
#  815: ['yoksa'],
#  816: ['beyaz'],
#  817: ['lisans'],
#  818: ['asıl', 'asl'],
#  819: ['altı'],
#  820: ['suç', 'suc'],
#  821: ['kargo'],
#  822: ['davranış'],
#  823: ['saç', 'sac'],
#  824: ['yazılı'],
#  825: ['takdir'],
#  826: ['görüş'],
#  827: ['kampanya'],
#  828: ['belli'],
#  829: ['be'],
#  830: ['zeka'],
#  831: ['zengin'],
#  832: ['giz'],
#  833: ['gol'],
#  834: ['evet'],
#  835: ['ciddi'],
#  836: ['net', 'ned'],
#  837: ['çift'],
#  838: ['oy'],
#  839: ['öğretmen'],
#  840: ['deste'],
#  841: ['popüler'],
#  842: ['uluslararası'],
#  843: ['sohbet'],
#  844: ['harika'],
#  845: ['normal'],
#  846: ['cinsel'],
#  847: ['anlaşma'],
#  848: ['yabancı'],
#  849: ['asker'],
#  850: ['şiddet'],
#  851: ['eriş'],
#  852: ['yerel'],
#  853: ['hüküm', 'hükm'],
#  854: ['öldür'],
#  856: ['kanun'],
#  857: ['kapat', 'kapad'],
#  858: ['inşa'],
#  859: ['elektronik', 'elektroniğ'],
#  860: ['polis'],
#  861: ['buluş'],
#  862: ['em'],
#  863: ['temsil'],
#  864: ['yönetici'],
#  865: ['ortalama'],
#  866: ['hatta'],
#  867: ['arada'],
#  868: ['yüzey'],
#  869: ['hisset', 'hissed'],
#  870: ['ünlü'],
#  871: ['doktor'],
#  872: ['belge'],
#  873: ['aktif'],
#  874: ['örnek', 'örneğ'],
#  875: ['dinle', 'dinli'],
#  876: ['aland'],
#  877: ['dost'],
#  878: ['oğ'],
#  879: ['hurda'],
#  880: ['tane'],
#  881: ['esas'],
#  882: ['eğlence'],
#  883: ['girişim'],
#  884: ['siyasi'],
#  885: ['vi'],
#  886: ['doğa'],
#  887: ['kesin'],
#  888: ['tal'],
#  889: ['koru'],
#  890: ['ekip', 'ekib'],
#  891: ['güneş'],
#  892: ['ada', 'adı'],
#  893: ['televizyon'],
#  894: ['tatlı'],
#  895: ['kenar'],
#  896: ['avantaj'],
#  897: ['personel'],
#  898: ['engel'],
#  899: ['deli'],
#  900: ['kamu'],
#  901: ['anahtar'],
#  902: ['not'],
#  903: ['duvar'],
#  904: ['kala'],
#  905: ['kuvvet', 'kuvved'],
#  906: ['hipotez'],
#  907: ['fizik', 'fiziğ'],
#  908: ['san'],
#  909: ['boy'],
#  910: ['anı'],
#  911: ['topla'],
#  912: ['basın'],
#  913: ['hükümet'],
#  914: ['yat'],
#  915: ['yet'],
#  916: ['yapay'],
#  917: ['henüz'],
#  918: ['hediye'],
#  919: ['bağımsız'],
#  920: ['yatır'],
#  921: ['uğra'],
#  922: ['gelişim'],
#  923: ['vb'],
#  924: ['karşıla', 'karşılı'],
#  925: ['kilo'],
#  926: ['ticaret'],
#  927: ['tablo'],
#  928: ['şüphe'],
#  929: ['gerekçe'],
#  930: ['tehlike'],
#  931: ['temiz'],
#  932: ['pratik', 'pratiğ'],
#  933: ['seri'],
#  934: ['odak', 'odağ'],
#  935: ['onay'],
#  936: ['birinci'],
#  937: ['ekonomi'],
#  938: ['hastane'],
#  939: ['duyu'],
#  940: ['siyaset'],
#  941: ['eşit'],
#  942: ['ordu'],
#  943: ['standart', 'standard'],
#  944: ['met'],
#  945: ['yarış'],
#  946: ['yüksel'],
#  947: ['özgür'],
#  948: ['çerçeve'],
#  949: ['belediye'],
#  950: ['çıkış'],
#  951: ['zevk'],
#  952: ['gemi'],
#  953: ['yavaş'],
#  954: ['kafa'],
#  955: ['çıkı'],
#  956: ['po'],
#  957: ['halı'],
#  958: ['otur'],
#  959: ['acı'],
#  960: ['hepsi'],
#  961: ['tartış'],
#  962: ['ışık', 'ışığ'],
#  963: ['mükemmel'],
#  964: ['denklem'],
#  965: ['sert', 'serd'],
#  966: ['aşırı'],
#  967: ['kavram'],
#  968: ['terim'],
#  969: ['kutu'],
#  970: ['heyecan'],
#  971: ['sınav'],
#  972: ['bildir'],
#  973: ['teşvik', 'teşviğ'],
#  974: ['çap', 'çab'],
#  975: ['müdahale'],
#  976: ['tepki'],
#  977: ['merak'],
#  978: ['bek', 'beğ'],
#  979: ['mahkeme'],
#  980: ['şikayet'],
#  981: ['ticari'],
#  982: ['zaten'],
#  983: ['besle', 'besli'],
#  984: ['keyif', 'keyf'],
#  985: ['ileri'],
#  986: ['eyalet'],
#  987: ['tesis'],
#  988: ['boş'],
#  989: ['giy'],
#  990: ['yangın'],
#  991: ['kırmızı'],
#  992: ['kork'],
#  993: ['vüc'],
#  994: ['silah'],
#  995: ['becer'],
#  996: ['ser'],
#  997: ['ateş'],
#  998: ['hoş'],
#  999: ['etraf'],
#  1000: ['otel'],
#  1001: ['mekan'],
#  1002: ['ağrı'],
#  ...}

# %%
len(myDict)
# Out:
# 32274

# %%
myids = tt.tokenize("merhaba dünya nasılsın")["ids"]
myids
# Out:
# [2036, 1, 224, 1, 171, 22286, 22284]

# %%
print(myDict[4536])
print(myDict[2036])
print(myDict[22286])
# Out:
# ['pırlanta']
# ['merhaba']
# ['sı', 'si', 'su', 'sü']

# %%
myDict[4536]
# Out:
# ['pırlanta']

# %%
def first_vowel(word):
    for i in range(len(word)):
        if word[i] in vowels:
            return i
    return -1


def suffix_i_to_i(word):
    variations = [word]
    variations.append(word[:first_vowel(word)] + "i" + word[first_vowel(word)+1:])
    variations.append(word[:first_vowel(word)] + "ı" + word[first_vowel(word)+1:])
    variations.append(word[:first_vowel(word)] + "u" + word[first_vowel(word)+1:])
    variations.append(word[:first_vowel(word)] + "ü" + word[first_vowel(word)+1:])
    variations = list(set(variations))
    return variations

# %%
vowels = ["a", "e", "ı", "i", "o", "ö", "u", "ü"]
suffix_i_to_i("dünya")
# Out:
# ['dinya', 'dınya', 'dunya', 'dünya']

# %%
sa = ["merhaba", "dünya", "nasılsın"]
sa[1][first_vowel(sa[1])]
# Out:
# 'ü'

# %%
tt.decode_text(myids)
# Out:
# merhaba
# merhaba
# merhaba
# merhaba
# merhaba
# hoşgeldin
# while girdi
# den ten girdi
# den ten girdi
# den ten girdi
# den ten girdi
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tt.decode_text(myids)
#
# File ~/Development/tokenizer/turkish_tokenizer/turkish_tokenizer.py:364, in decode_text(list)
#     362     result += choose_correct_version(cur_token, reverse_dict[next_token], reverse_dict[prev_token])
#     363 else:
# --> 364     result += choose_correct_version(cur_token, reverse_dict[next_token][0], reverse_dict[prev_token][0])
#     365 prev_token = cur_token
#     366 continue
#
# File ~/Development/tokenizer/turkish_tokenizer/turkish_tokenizer.py:305, in choose_correct_version(cur_token, next_token, prev_token)
#     303 #ler lar
#     304 for i in range(len(tokens)):
# --> 305     fv_index = first_vowel(tokens[i])
#     306     if fv_index is None or fv_index == -1 or fv_index >= len(tokens[i]):
#     307         continue
#
# IndexError: list index out of range
