# %%
import json

with open('kokler_v01.json', 'r') as f:
    tokenizer_dict = json.load(f)

with open('ekler.json', 'r') as f:
    ekler_dict = json.load(f)


counter = 0
ekler_v01 = {}
# chek if any ek in tokenizer_dict
for _, value in ekler_dict.items():
  for ek in value:
    counter += 1
    ekler_v01[ek] = counter
    if ek in tokenizer_dict:
      print(ek)

print(counter)

with open('ekler_v01.json', 'w', encoding='utf-8') as f:
  json.dump(ekler_v01, f, ensure_ascii=False)
# Out:
# lar
# ler
# i
# yı
# yu
# yü
# ya
# ye
# da
# de
# ta
# te
# dan
# tan
# ten
# ın
# in
# un
# ün
# nın
# nun
# la
# le
# yla
# yle
# ım
# im
# um
# üm
# ız
# iz
# uz
# üz
# ımız
# nız
# sı
# si
# su
# ları
# leri
# mı
# mi
# mu
# mü
# mak
# mek
# ma
# yor
# makta
# ar
# er
# meli
# sa
# se
# dı
# di
# du
# dü
# tı
# ti
# tu
# tü
# mış
# miş
# muş
# mış
# miş
# muş
# dı
# di
# du
# dü
# tı
# ti
# tu
# tü
# lık
# luk
# lük
# cu
# cü
# çi
# çü
# leş
# cık
# cuk
# ça
# ce
# çe
# daş
# deş
# sal
# sel
# dır
# dur
# dür
# tır
# tir
# tur
# tür
# ki
# idi
# imiş
# ise
# lı
# lu
# sız
# siz
# süz
# ncı
# nci
# ar
# er
# şar
# şer
# cu
# gül
# kıl
# kil
# ka
# ge
# kan
# lak
# sak
# sek
# rek
# sa
# se
# gibi
# için
# kadar
# üzere
# doğru
# önce
# sonra
# karşı
# göre
# rağmen
# beri
# yönelik
# ait
# ve
# ama
# de
# çünkü
# eğer
# fakat
# lakin
# ki
# ya
# yahut
# veya
# hem
# nitekim
# zira
# ancak
# bari
# ey
# oha
# öf
# hah
# ya
# aman
# hey
# vah
# eyvah
# of
# oh
# 254

# %%
# remove ek from tokenizer_dict
for ek in ekler_v01:
  if ek in tokenizer_dict:
    del tokenizer_dict[ek]

with open('kokler_v01.json', 'w', encoding='utf-8') as f:
  json.dump(tokenizer_dict, f, ensure_ascii=False)
